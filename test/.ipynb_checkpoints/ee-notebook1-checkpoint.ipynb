# %%
from fido.earth import EarthExplorer

# %%
ee = EarthExplorer()

# %%
api_key = ee.login(username='tonybutzer', password="##100best")

# %%
ds = ee.datasets(apiKey=api_key)

# %%
print(ds)
# Out:
# [{'datasetFullName': ' Landsat 7 Enhanced Thematic Mapper Plus Collection 1 Level-1', 'supportCloudCover': True, 'orderLimit': 500, 'supportOrder': True, 'startDate': '1999-05-28', 'endDate': '2018-11-08', 'supportDownload': True, 'bulkDownloadOrderLimit': 15000, 'bounds': {'south': -55.5043, 'east': 176.9874, 'west': -125.9179, 'north': 72.0098}, 'datasetName': 'LANDSAT_ETM_C1', 'supportBulkDownload': True, 'lastModifiedDate': '2018-11-08', 'idnEntryId': '', 'totalScenes': 2565667, 'supportDeletionSearch': False}, {'datasetFullName': ' MCD43D28: MODIS/Terra and Aqua BRDF/Albedo Parameter 1 Shortwave Daily L3 Global 30 ArcSec CMG Version 6\n', 'supportCloudCover': False, 'orderLimit': 0, 'supportOrder': False, 'startDate': '2000-02-16', 'endDate': '2018-10-13', 'supportDownload': True, 'bulkDownloadOrderLimit': 0, 'bounds': {'south': -85, 'east': -179.99, 'west': 179.99, 'north': 85}, 'datasetName': 'MODIS_MCD43D28_V6', 'supportBulkDownload': False, 'lastModifiedDate': '2018-11-08', 'idnEntryId': '', 'totalScenes': 6813, 'supportDeletionSearch': False}, {'datasetFullName': 'ALOS Palsar 1.1 Radar Processing System', 'supportCloudCover': False, 'orderLimit': 0, 'supportOrder': False, 'startDate': '2006-05-16', 'endDate': '2011-04-21', 'supportDownload': False, 'bulkDownloadOrderLimit': 0, 'bounds': {'south': -77.649, 'east': 179.163, 'west': -164.746, 'north': 84.26}, 'datasetName': 'ALOS_PALSAR_11_PUB', 'supportBulkDownload': False, 'lastModifiedDate': '2018-07-27', 'idnEntryId': '', 'totalScenes': 134480, 'supportDeletionSearch': False}, {'datasetFullName': 'ALOS Palsar 1.5 Radar Processing System', 'supportCloudCover': False, 'orderLimit': 0, 'supportOrder': False, 'startDate': '2006-05-16', 'endDate': '2011-04-07', 'supportDownload': False, 'bulkDownloadOrderLimit': 0, 'bounds': {'south': -79.999, 'east': 179.41, 'west': -165.859, 'north': 85}, 'datasetName': 'ALOS_PALSAR_15_PUB', 'supportBulkDownload': False, 'lastModifiedDate': '2018-07-27', 'idnEntryId': '', 'totalScenes': 245286, 'supportDeletionSearch': False}, {'datasetFullName': 'ALOS Palser 1.0 Radar Processing System', 'supportCloudCover': False, 'orderLimit': 0, 'supportOrder': False, 'startDate': '2006-05-16', 'endDate': '2011-03-17', 'supportDownload': True, 'bulkDownloadOrderLimit': 500, 'bounds': {'south': -77.6699, 'east': 178.8185, 'west': -171.1608, 'north': 84.3594}, 'datasetName': 'SPS_ALOS_PALSAR_PUB', 'supportBulkDownload': True, 'lastModifiedDate': '2018-07-27', 'idnEntryId': '', 'totalScenes': 145008, 'supportDeletionSearch': False}, {'datasetFullName': "ASAS = NASA's Advanced Solid-state Array Spectroradiometer: 1988 -2000", 'supportCloudCover': False, 'orderLimit': 0, 'supportOrder': False, 'startDate': '1988-06-26', 'endDate': '1994-03-25', 'supportDownload': True, 'bulkDownloadOrderLimit': 500, 'bounds': {'south': 0, 'east': 2.6841, 'west': -123.9363, 'north': 48.8415}, 'datasetName': 'ASAS', 'supportBulkDownload': True, 'lastModifiedDate': '2018-07-27', 'idnEntryId': '', 'totalScenes': 162, 'supportDeletionSearch': False}, {'datasetFullName': 'ASTER GLOBAL Digital Elevation Model V002', 'supportCloudCover': False, 'orderLimit': 0, 'supportOrder': False, 'startDate': '2011-10-17', 'endDate': '2011-10-17', 'supportDownload': True, 'bulkDownloadOrderLimit': 0, 'bounds': {'south': -83.0001, 'east': 167.0001, 'west': -170.0001, 'north': 83.0001}, 'datasetName': 'ASTER_GLOBAL_DEM_DE', 'supportBulkDownload': False, 'lastModifiedDate': '2018-07-27', 'idnEntryId': '', 'totalScenes': 22702, 'supportDeletionSearch': False}, {'datasetFullName': 'ASTER Global Digital Elevation Model V002', 'supportCloudCover': False, 'orderLimit': 0, 'supportOrder': False, 'startDate': '2011-10-17', 'endDate': '2011-10-17', 'supportDownload': True, 'bulkDownloadOrderLimit': 0, 'bounds': {'south': -83.0001, 'east': 167.0001, 'west': -170.0001, 'north': 83.0001}, 'datasetName': 'ASTER_GLOBAL_DEM', 'supportBulkDownload': False, 'lastModifiedDate': '2018-07-27', 'idnEntryId': '',  ...

# %%
for d in ds:
    if 'ARD' in d['datasetFullName']:
        print(d['datasetFullName'])
        print(d)
# Out:
# U.S. Landsat 4-8 Analysis Ready Data (ARD) Level-2 Tiles (Albers projection)
# {'datasetFullName': 'U.S. Landsat 4-8 Analysis Ready Data (ARD) Level-2 Tiles (Albers projection)', 'supportCloudCover': True, 'orderLimit': 100, 'supportOrder': True, 'startDate': '1982-11-11', 'endDate': '2018-09-09', 'supportDownload': True, 'bulkDownloadOrderLimit': 500, 'bounds': {'south': 23.0284, 'east': -64.4405, 'west': -128.5965, 'north': 51.5332}, 'datasetName': 'ARD_TILE', 'supportBulkDownload': True, 'lastModifiedDate': '2018-11-08', 'idnEntryId': '', 'totalScenes': 1445864, 'supportDeletionSearch': True}

# %%
ds = ee.datasetfields(apiKey=api_key, datasetName='ARD_TILE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-419ca5188334> in <module>
# ----> 1 ds = ee.datasetfields(apiKey=api_key, datasetName='ARD_TILE')
#
# AttributeError: 'EarthExplorer' object has no attribute 'datasetfields'
